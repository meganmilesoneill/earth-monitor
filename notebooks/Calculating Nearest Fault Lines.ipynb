# %%
import osgeo.ogr

# %%
import psycopg2

# %%
import numpy as np

# %%
import shapely

# %%
import shapely.wkt

# %%
import shapely.ops

# %%
import pyproj

# %%
import pandas as pd
from pandas import DataFrame, Series

def getDataFrame(databaseName, query):
    connection = psycopg2.connect(database=databaseName)
    cursor = connection.cursor()
    cursor.execute(query)
    colnames = [desc[0] for desc in cursor.description]
    rows = cursor.fetchall()
    dataframe = DataFrame(rows, columns=colnames)
    cursor.close()
    connection.close()
    
    return dataframe

# %%
src_proj = pyproj.Proj(proj="longlat", ellps="WGS84", datum="WGS84")

# %%
dst_proj = pyproj.Proj(proj="moll", lon_0=0, x_0=0, y_0=0, ellps="WGS84", datum="WGS84", units="m")

# %%
def latlong_to_mollweide(longitude, latitude, depth=0):
    return pyproj.transform(src_proj, dst_proj, longitude, latitude)

# %%
def transformWkt(wkt):
    geometry = shapely.wkt.loads(wkt)
    #eq_point = shapely.geometry.Point(eq_geometry.x, eq_geometry.y)        
    return shapely.ops.transform(latlong_to_mollweide, geometry)

# %%
def getNearestFaults(earthquake, faults):
    #transform the earthquake point geometry to the mollewide project and then buffer it by 20km
    eq_transformed = transformWkt(earthquake.geometry.values[0]).buffer(10000)
    
    tgeo = faults.geometry.apply(lambda x: transformWkt(x))
    tgeo_index = tgeo.apply(lambda x:x.intersects(eq_transformed))
    
    return faults[tgeo_index]

# %%
eq = getDataFrame("earth-monitor", "SELECT id, place, ST_AsText(geometry) as geometry FROM earthquakes;")

# %%
ft = getDataFrame("earth-monitor", "SELECT id, faultid, name, ST_AsText(geometry) as geometry FROM faults;")

# %% [markdown]
# Get a list of events that have "Hayward" in the place field.  This will allow us to gut check the results.

# %%
eq[eq.place.apply(lambda x: x.find("Hayward") > 0)]
# Out:
#             id                           place  \
# 6943     14162  2km ESE of Hayward, California
# 29510    36692   2km SE of Hayward, California
# 29562    36742  1km WSW of Hayward, California
# 33588    40736  2km SSE of Hayward, California
# 62578    69714   4km SE of Hayward, California
# 67850    74993   1km SE of Hayward, California
# 69648    76792   0km SE of Hayward, California
# 70420    77564   2km SE of Hayward, California
# 90349    97525   3km SE of Hayward, California
# 102167  109358   4km SE of Hayward, California
# 102484  109677   3km SE of Hayward, California
# 105730  112940   1km SE of Hayward, California
# 120297  127385   3km SE of Hayward, California
# 124112  131187   4km SE of Hayward, California
# 145180  152401   1km SE of Hayward, California
# 157086  164204  0km SSW of Hayward, California
# 170276  177492   3km SE of Hayward, California
# 177683  184883   2km SE of Hayward, California
# 177697  184897   3km SE of Hayward, California
# 206232  213436  1km ESE of Hayward, California
# 206697  213899   3km SE of Hayward, California
# 207976  215177   2km SE of Hayward, California
# 210962  218157   4km SE of Hayward, California
# 211068  218262  3km SSE of Hayward, California
# 211614  218804   3km SE of Hayward, California
# 212397  219587   2km SE of Hayward, California
# 213598  220786  1km ESE of Hayward, California
# 214530  221716   3km SE of Hayward, California
# 216092  223273  0km ENE of Hayward, California
# 219547  226675    0km N of Hayward, California
# 232939  240160   2km SE of Hayward, California
# 238765  245989   4km SE of Hayward, California
# 243957  251182    0km N of Hayward, California
# 276003  283227   4km SE of Hayward, California
# 279403  286628   1km SE of Hayward, California
# 282124  289349   3km SE of Hayward, California
# 282182  289405   2km SE of Hayward, California
# 284692  291906   3km SE of Hayward, California
# 292859  300083   4km SE of Hayward, California
# 295272  302491  0km NNE of Hayward, California
# 301917  309138   3km SE of Hayward, California
# 308850  316066   4km SE of Hayward, California
# 315848  323073   2km SE of Hayward, California
# 330012  337188   1km SE of Hayward, California
#
#                                       geometry
# 6943           POINT Z (-122.0578 37.6572 4.7)
# 29510            POINT Z (-122.0653 37.6537 5)
# 29562          POINT Z (-122.0973 37.6643 4.5)
# 33588           POINT Z (-122.068 37.6513 5.5)
# 62578          POINT Z (-122.0483 37.6385 1.5)
# 67850      POINT Z (-122.0648333 37.6595 7.12)
# 69648          POINT Z (-122.0742 37.6635 2.6)
# 70420          POINT Z (-122.0617 37.6572 4.5)
# 90349          POINT Z (-122.0548 37.6435 0.5)
# 102167         POINT Z (-122.0503 37.6387 1.3)
# 102484         POINT Z (-122.0547 37.6398 1.3)
# 105730         POINT Z (-122.0732 37.6608 5.6)
# 120297          POINT Z (-122.0518 37.645 4.5)
# 124112           POINT Z (-122.0458 37.6412 4)
# 145180     POINT Z (-122.0711667 37.6625 3.77)
# 157086         POINT Z (-122.0815 37.6663 6.7)
# 170276     POINT Z (-122.0505 37.6458333 5.39)
# 177683  POINT Z (-122.0583333 37.6526667 5.31)
# 177697  POINT Z (-122.0533333 37.6511667 4.96)
# 206232  POINT Z (-122.0658333 37.6621667 6.05)
# 206697        POINT Z (-122.0535 37.6465 4.97)
# 207976      POINT Z (-122.066 37.6513333 1.91)
# 210962  POINT Z (-122.0523333 37.6406667 1.22)
# 211068         POINT Z (-122.0585 37.642 0.33)
# 211614  POINT Z (-122.0528333 37.6421667 1.37)
# 212397     POINT Z (-122.0616667 37.6555 3.92)
# 213598      POINT Z (-122.0608333 37.662 5.08)
# 214530     POINT Z (-122.0575 37.6418333 1.42)
# 216092     POINT Z (-122.0773333 37.6695 4.78)
# 219547  POINT Z (-122.0788333 37.6771667 8.79)
# 232939  POINT Z (-122.0613333 37.6538333 4.53)
# 238765  POINT Z (-122.0471667 37.6378333 1.69)
# 243957     POINT Z (-122.0795 37.6741667 4.36)
# 276003  POINT Z (-122.0436667 37.6361667 2.75)
# 279403  POINT Z (-122.0673333 37.6581667 5.25)
# 282124         POINT Z (-122.0585 37.643 1.76)
# 282182  POINT Z (-122.0606667 37.6486667 7.09)
# 284692  POINT Z (-122.0498333 37.6438333 3.08)
# 292859     POINT Z (-122.0483333 37.6355 1.88)
# 295272     POINT Z (-122.0805 37.6698333 4.11)
# 301917  POINT Z (-122.0588333 37.6461667 1.73)
# 308850  POINT Z (-122.0456667 37.6356667 1.68)
# 315848  POINT Z (-122.0601667 37.6566667 4.65)
# 330012     POINT Z (-122.0653333 37.6565 4.03)

# %% [markdown]
# Select one of the events from the list of Hayward events above.

# %%
test_eq = eq[eq.id == 36692]

# %%
test_eq
# Out:
#           id                          place                       geometry
# 29510  36692  2km SE of Hayward, California  POINT Z (-122.0653 37.6537 5)

# %%
nearest_faults = getNearestFaults(test_eq, ft)

# %%
nearest_faults
# Out:
#         id faultid                                               name  \
# 1007   997      55  Hayward fault zone, southern Hayward section (...
# 1047  1028      55  Hayward fault zone, southern Hayward section (...
# 1049  1029      55  Hayward fault zone, southern Hayward section (...
# 1504  1469     380                                       Chabot fault
# 1509  1468     380                                       Chabot fault
# 1510  1470     380                                       Chabot fault
# 1512  1472     380                                       Chabot fault
# 1980  1906      55  Hayward fault zone, northern Hayward section (...
# 2204  2103      55  Hayward fault zone, southern Hayward section (...
# 2266  2163      55  Hayward fault zone, northern Hayward section (...
# 2269  2164      55  Hayward fault zone, southern Hayward section (...
# 2918  2797     379                                 Miller Creek fault
# 2950  2823     359                                      Mission fault
# 2965  2842     359                                      Mission fault
# 4982  4882      54   Calaveras fault zone, northern Calaveras section
# 5154  5040      55       Hayward fault zone, northern Hayward section
# 6199  6383      55  Hayward fault zone, southern Hayward section (...
#
#                                                geometry
# 1007  MULTILINESTRING((-122.108140085396 37.69764849...
# 1047  MULTILINESTRING((-122.125805699473 37.71016507...
# 1049  MULTILINESTRING((-122.126075711025 37.71071005...
# 1504  LINESTRING(-122.005410161149 37.607187072926,-...
# 1509  MULTILINESTRING((-121.994584911064 37.58765584...
# 1510  MULTILINESTRING((-121.974258223737 37.58942059...
# 1512  MULTILINESTRING((-121.970903150859 37.57839101...
# 1980  MULTILINESTRING((-122.124224702108 37.72369357...
# 2204  LINESTRING(-122.123428667199 37.7216986492741,...
# 2266  MULTILINESTRING((-122.135347140358 37.73770610...
# 2269  MULTILINESTRING((-122.018874505054 37.60895697...
# 2918  MULTILINESTRING((-122.024110407469 37.69909926...
# 2950  MULTILINESTRING((-121.982011469753 37.59320450...
# 2965  LINESTRING(-121.970485145073 37.575868111625,-...
# 4982  LINESTRING(-121.905721916732 37.5961927529941,...
# 5154  MULTILINESTRING((-122.151087688146 37.73882612...
# 6199  MULTILINESTRING((-121.9269878614 37.5028944776...

# %%
test_eq2 = eq[eq.id == 177492]

# %%
test_eq2
# Out:
#             id                          place  \
# 170276  177492  3km SE of Hayward, California
#
#                                    geometry
# 170276  POINT Z (-122.0505 37.6458333 5.39)

# %%
nearest_faults2 = getNearestFaults(test_eq2, ft)

# %%
nearest_faults2
# Out:
#         id faultid                                               name  \
# 1007   997      55  Hayward fault zone, southern Hayward section (...
# 1047  1028      55  Hayward fault zone, southern Hayward section (...
# 1049  1029      55  Hayward fault zone, southern Hayward section (...
# 1504  1469     380                                       Chabot fault
# 1509  1468     380                                       Chabot fault
# 1510  1470     380                                       Chabot fault
# 1512  1472     380                                       Chabot fault
# 1980  1906      55  Hayward fault zone, northern Hayward section (...
# 2204  2103      55  Hayward fault zone, southern Hayward section (...
# 2269  2164      55  Hayward fault zone, southern Hayward section (...
# 2918  2797     379                                 Miller Creek fault
# 2950  2823     359                                      Mission fault
# 2965  2842     359                                      Mission fault
# 4980  4881      54   Calaveras fault zone, northern Calaveras section
# 4982  4882      54   Calaveras fault zone, northern Calaveras section
# 6199  6383      55  Hayward fault zone, southern Hayward section (...
#
#                                                geometry
# 1007  MULTILINESTRING((-122.108140085396 37.69764849...
# 1047  MULTILINESTRING((-122.125805699473 37.71016507...
# 1049  MULTILINESTRING((-122.126075711025 37.71071005...
# 1504  LINESTRING(-122.005410161149 37.607187072926,-...
# 1509  MULTILINESTRING((-121.994584911064 37.58765584...
# 1510  MULTILINESTRING((-121.974258223737 37.58942059...
# 1512  MULTILINESTRING((-121.970903150859 37.57839101...
# 1980  MULTILINESTRING((-122.124224702108 37.72369357...
# 2204  LINESTRING(-122.123428667199 37.7216986492741,...
# 2269  MULTILINESTRING((-122.018874505054 37.60895697...
# 2918  MULTILINESTRING((-122.024110407469 37.69909926...
# 2950  MULTILINESTRING((-121.982011469753 37.59320450...
# 2965  LINESTRING(-121.970485145073 37.575868111625,-...
# 4980  LINESTRING(-121.858537405476 37.5395203078169,...
# 4982  LINESTRING(-121.905721916732 37.5961927529941,...
# 6199  MULTILINESTRING((-121.9269878614 37.5028944776...

# %%
eq[eq.place.apply(lambda x: x.find("San Ramon") > 0)]
# Out:
#             id                             place  \
# 8890     16113  4km WNW of San Ramon, California
# 16208    23420  0km SSW of San Ramon, California
# 16909    24129  6km ESE of San Ramon, California
# 20753    27971    2km N of San Ramon, California
# 22455    29677   1km NE of San Ramon, California
# 27038    34245   2km NE of San Ramon, California
# 27040    34249  3km NNE of San Ramon, California
# 32897    40054  3km ESE of San Ramon, California
# 44249    51453  1km SSW of San Ramon, California
# 46393    53597  3km SSW of San Ramon, California
# 49331    56544   3km NE of San Ramon, California
# 49603    56820   2km NW of San Ramon, California
# 58622    65781  7km WSW of San Ramon, California
# 58628    65787  7km WSW of San Ramon, California
# 61293    68429    1km S of San Ramon, California
# 70198    77341  2km ESE of San Ramon, California
# 70441    77585    2km E of San Ramon, California
# 71231    78381  2km ESE of San Ramon, California
# 71232    78382  2km ESE of San Ramon, California
# 71241    78391  1km ENE of San Ramon, California
# 71277    78428  1km ENE of San Ramon, California
# 71489    78643  1km ENE of San Ramon, California
# 71491    78645  1km ENE of San Ramon, California
# 71494    78648    1km E of San Ramon, California
# 71499    78653    1km E of San Ramon, California
# 71530    78683    1km E of San Ramon, California
# 71534    78687  1km ENE of San Ramon, California
# 71539    78692  2km ENE of San Ramon, California
# 71596    78751  1km ENE of San Ramon, California
# 71890    79046    2km E of San Ramon, California
# ...        ...                               ...
# 308989  316204   2km NE of San Ramon, California
# 308999  316213  2km ENE of San Ramon, California
# 309021  316236  1km ENE of San Ramon, California
# 309121  316334  2km ENE of San Ramon, California
# 310473  317696   2km NE of San Ramon, California
# 310616  317840   1km NE of San Ramon, California
# 310620  317844    1km E of San Ramon, California
# 310621  317845   1km NE of San Ramon, California
# 310623  317846    1km E of San Ramon, California
# 311008  318232  1km ENE of San Ramon, California
# 311104  318327  3km NNE of San Ramon, California
# 311690  318908  1km ENE of San Ramon, California
# 314396  321620   1km NE of San Ramon, California
# 314525  321749  2km NNE of San Ramon, California
# 314929  322153   2km NE of San Ramon, California
# 316574  323798  1km ESE of San Ramon, California
# 316576  323800  1km ESE of San Ramon, California
# 316577  323801  1km ESE of San Ramon, California
# 316578  323802  1km ESE of San Ramon, California
# 316579  323803  1km ESE of San Ramon, California
# 316586  323810  1km ESE of San Ramon, California
# 316588  323812  1km ESE of San Ramon, California
# 316630  323854  1km ESE of San Ramon, California
# 316732  323957    1km E of San Ramon, California
# 321074  328296  1km ESE of San Ramon, California
# 325880  333105   1km SE of San Ramon, California
# 326087  333311   1km SE of San Ramon, California
# 326090  333314  1km ESE of San Ramon, California
# 329215  336415    0km E of San Ramon, California
# 334583  341801  2km ESE of San Ramon, California
#
#                                        geometry
# 8890            POINT Z (-122.0312 37.7898 5.5)
# 16208           POINT Z (-121.9788 37.778 13.7)
# 16909           POINT Z (-121.9043 37.7592 9.5)
# 20753          POINT Z (-121.9782 37.8005 19.3)
# 22455          POINT Z (-121.9652 37.7917 18.6)
# 27038          POINT Z (-121.9603 37.8002 19.3)
# 27040           POINT Z (-121.9588 37.803 18.9)
# 32897            POINT Z (-121.9383 37.768 9.9)
# 44249           POINT Z (-121.9848 37.7708 5.7)
# 46393           POINT Z (-121.9938 37.7492 7.3)
# 49331           POINT Z (-121.9545 37.8058 8.8)
# 49603          POINT Z (-121.9998 37.7985 14.2)
# 58622          POINT Z (-122.0588 37.7603 10.7)
# 58628            POINT Z (-122.0598 37.7585 11)
# 61293           POINT Z (-121.9765 37.762 10.1)
# 70198            POINT Z (-121.9467 37.775 7.8)
# 70441           POINT Z (-121.9445 37.7785 6.6)
# 71231           POINT Z (-121.9452 37.7743 5.9)
# 71232           POINT Z (-121.9548 37.7743 5.4)
# 71241           POINT Z (-121.9638 37.7835 9.7)
# 71277           POINT Z (-121.9603 37.7828 8.8)
# 71489          POINT Z (-121.9658 37.7863 10.3)
# 71491           POINT Z (-121.9577 37.7838 8.8)
# 71494            POINT Z (-121.956 37.7818 9.6)
# 71499            POINT Z (-121.957 37.7832 9.3)
# 71530          POINT Z (-121.9595 37.7827 10.4)
# 71534           POINT Z (-121.9638 37.7843 9.7)
# 71539            POINT Z (-121.9558 37.784 9.6)
# 71596           POINT Z (-121.9612 37.7848 9.4)
# 71890           POINT Z (-121.9523 37.7807 8.5)
# ...                                         ...
# 308989   POINT Z (-121.9576667 37.7923333 9.43)
# 308999          POINT Z (-121.9552 37.7895 8.2)
# 309021   POINT Z (-121.9611667 37.7851667 6.97)
# 309121         POINT Z (-121.9541667 37.7905 8)
# 310473   POINT Z (-121.9563333 37.7918333 9.08)
# 310616   POINT Z (-121.9673333 37.7863333 8.85)
# 310620   POINT Z (-121.9586667 37.7821667 8.07)
# 310621      POINT Z (-121.9615 37.7893333 8.51)
# 310623    POINT Z (-121.9591667 37.7816667 7.4)
# 311008      POINT Z (-121.9625 37.7846667 8.17)
# 311104       POINT Z (-121.9568333 37.805 8.12)
# 311690   POINT Z (-121.9606667 37.7853333 7.41)
# 314396      POINT Z (-121.9665 37.7896667 8.37)
# 314525   POINT Z (-121.9606667 37.8008333 7.57)
# 314929  POINT Z (-121.9593333 37.7926667 10.09)
# 316574   POINT Z (-121.9658333 37.7741667 7.99)
# 316576   POINT Z (-121.9683333 37.7748333 8.47)
# 316577       POINT Z (-121.964 37.7768333 8.59)
# 316578   POINT Z (-121.9631667 37.7763333 8.18)
# 316579       POINT Z (-121.9613333 37.776 8.19)
# 316586       POINT Z (-121.9633333 37.775 8.27)
# 316588    POINT Z (-121.9666667 37.7746667 8.4)
# 316630   POINT Z (-121.9653333 37.7751667 7.72)
# 316732       POINT Z (-121.958 37.7778333 8.49)
# 321074   POINT Z (-121.9603333 37.7743333 8.34)
# 325880   POINT Z (-121.9633333 37.7718333 8.11)
# 326087   POINT Z (-121.9651667 37.7673333 8.46)
# 326090           POINT Z (-121.964 37.773 7.31)
# 329215   POINT Z (-121.9671667 37.7791667 8.43)
# 334583    POINT Z (-121.956665 37.7716675 7.15)
#
# [791 rows x 3 columns]

# %%
test_eq3 = eq[eq.id == 323812]

# %%
test_eq3
# Out:
#             id                             place  \
# 316588  323812  1km ESE of San Ramon, California
#
#                                      geometry
# 316588  POINT Z (-121.9666667 37.7746667 8.4)

# %%
nearest_faults3 = getNearestFaults(test_eq3, ft)

# %%
nearest_faults3
# Out:
#         id faultid                                               name  \
# 1351  1315      54  Calaveras fault zone, northern Calaveras secti...
# 1360  1328      54  Calaveras fault zone, northern Calaveras secti...
# 1370  1335      54  Calaveras fault zone, northern Calaveras secti...
# 1376  1342      54  Calaveras fault zone, northern Calaveras secti...
# 1397  1361      54  Calaveras fault zone, northern Calaveras secti...
# 2007  1930     480                                     Franklin fault
# 2108  2026      54  Calaveras fault zone, northern Calaveras secti...
# 2951  2824     399                                        Mocho fault
# 2985  2858     376                                       Moraga fault
# 3165  3030      54  Calaveras fault zone, northern Calaveras secti...
# 3182  3041      54  Calaveras fault zone, northern Calaveras secti...
# 3450  3306     238                                   Pleasanton fault
# 3451  3307     238                                   Pleasanton fault
# 3452  3308     238                                   Pleasanton fault
# 4162  4012     400                       Sherburne Hills thrust fault
# 4329  4187     481                                  Southampton fault
# 5368  5271    None                                      unnamed fault
#
#                                                geometry
# 1351  LINESTRING(-121.951606028095 37.7323957738468,...
# 1360  MULTILINESTRING((-121.834748599867 37.50984902...
# 1370  MULTILINESTRING((-121.831640469132 37.49795936...
# 1376  LINESTRING(-121.999820630917 37.7997507502978,...
# 1397  MULTILINESTRING((-121.831639471784 37.49808536...
# 2007  MULTILINESTRING((-122.042686226288 37.84936159...
# 2108  MULTILINESTRING((-121.982796045501 37.78154123...
# 2951  LINESTRING(-121.82040904564 37.7048045392989,-...
# 2985  MULTILINESTRING((-122.097016889018 37.77934770...
# 3165  MULTILINESTRING((-121.982490037684 37.78199722...
# 3182  MULTILINESTRING((-121.986697210108 37.79269894...
# 3450  MULTILINESTRING((-121.901414557136 37.70508672...
# 3451  LINESTRING(-121.910058786683 37.7233540691359,...
# 3452  MULTILINESTRING((-121.874039783109 37.65156054...
# 4162  MULTILINESTRING((-121.921930135367 37.76182276...
# 4329  MULTILINESTRING((-122.095741993897 37.87759305...
# 5368  MULTILINESTRING((-117.003080370362 32.55447910...
